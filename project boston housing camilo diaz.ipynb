# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import datetime
import scipy.stats

# %%
df = pd.read_csv("boston_housing (1).csv")

# %%
df
# Out:
#      Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0             0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1             1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2             2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3             3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4             4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502         502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503         503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# 504         504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0
# 505         505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0
#
#        TAX  PTRATIO  LSTAT  MEDV
# ...

# %% [markdown]
# Exploratory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   CRIM        506 non-null    float64
#  2   ZN          506 non-null    float64
#  3   INDUS       506 non-null    float64
#  4   CHAS        506 non-null    float64
#  5   NOX         506 non-null    float64
#  6   RM          506 non-null    float64
#  7   AGE         506 non-null    float64
#  8   DIS         506 non-null    float64
#  9   RAD         506 non-null    float64
#  10  TAX         506 non-null    float64
#  11  PTRATIO     506 non-null    float64
#  12  LSTAT       506 non-null    float64
#  13  MEDV        506 non-null    float64
# dtypes: float64(13), int64(1)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#        Unnamed: 0        CRIM          ZN       INDUS        CHAS         NOX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   252.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      0.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    126.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    252.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    378.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    505.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %% [markdown]
# Visualization

# %%
df.hist(bins=50, figsize=(20,10))
plt.suptitle('characteristics Distribution', x=0.5, y=1.02, ha='center', fontsize='large')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.suptitle('Pairplots', x=0.4, y=1.0, ha='center', fontsize='large')
sns.pairplot(df.sample(240))
plt.show()

# %% [markdown]
# Descriptive Statistics and Visualizations

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df.MEDV)
plt.title("Boxplot MEDV")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.distplot(a=df.CHAS,bins=10, kde=False)
plt.title("Histogram")
# Out:
# C:\Users\Deferex\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Histogram')

# %%
df.loc[(df["AGE"] <= 35),'age_group'] = '35 years and younger'
df.loc[(df["AGE"] > 35) & (df["AGE"]<70),'age_group'] = 'between 35 and 70 years'
df.loc[(df["AGE"] >= 70),'age_group'] = '70 years and older'

# %%
df
# Out:
#      Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0             0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1             1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2             2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3             3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4             4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502         502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503         503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# 504         504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0
# 505         505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0
#
# ...

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x=df.MEDV, y=df.age_group, data=df)
plt.title("Boxplot for the MEDV and Age variable")
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x=df.NOX, y=df.INDUS, data=df)
plt.title("Relationship NOX & INDUS")
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.distplot(a=df.PTRATIO,bins=10, kde=False)
plt.title("Histogram teacher ratio variable")
plt.show()

# %% [markdown]
# Is there a significant difference in median value of houses bounded by the Charles river or not? (T-test for independent samples)

# %%
df["CHAS"].value_counts()
# Out:
# 0.0    471
# 1.0     35
# Name: CHAS, dtype: int64

# %%
a = df[df["CHAS"] == 0]["MEDV"]
a
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 471, dtype: float64

# %%
b = df[df["CHAS"] == 1]["MEDV"]
b
# Out:
# 142    13.4
# 152    15.3
# 154    17.0
# 155    15.6
# 160    27.0
# 162    50.0
# 163    50.0
# 208    24.4
# 209    20.0
# 210    21.7
# 211    19.3
# 212    22.4
# 216    23.3
# 218    21.5
# 219    23.0
# 220    26.7
# 221    21.7
# 222    27.5
# 234    29.0
# 236    25.1
# 269    20.7
# 273    35.2
# 274    32.4
# 276    33.2
# 277    33.1
# 282    46.0
# 283    50.0
# 356    17.8
# 357    21.7
# 358    22.7
# 363    16.8
# 364    21.9
# 369    50.0
# 370    50.0
# 372    50.0
# Name: MEDV, dtype: float64

# %%
scipy.stats.ttest_ind(a,b,axis=0,equal_var=True)
# Out:
# Ttest_indResult(statistic=-3.996437466090509, pvalue=7.390623170519905e-05)

# %% [markdown]
# Since the p-value exceeds the significance level of 0.05, we refrain from rejecting the null hypothesis due to a lack of statistical significance.

# %% [markdown]
# Is there a difference in Median values of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE)? (ANOVA)

# %%
df["AGE"].value_counts()
# Out:
# 100.0    43
# 95.4      4
# 96.0      4
# 98.2      4
# 97.9      4
#          ..
# 58.4      1
# 74.4      1
# 73.4      1
# 33.1      1
# 89.3      1
# Name: AGE, Length: 356, dtype: int64

# %%
df.loc[(df["AGE"] <= 35),'age_group'] = '35 years and younger'
df.loc[(df["AGE"] > 35) & (df["AGE"]<70),'age_group'] = 'between 35 and 70 years'
df.loc[(df["AGE"] >= 70),'age_group'] = '70 years and older'

# %%
df
# Out:
#      Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0             0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1             1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2             2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3             3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4             4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502         502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503         503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# 504         504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0
# 505         505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0
#
# ...

# %%
l = df[df["age_group"] == '35 years and younger']["MEDV"]
m = df[df["age_group"] == 'between 35 and 70 years']["MEDV"]
h = df[df["age_group"] == '70 years and older']["MEDV"]

# %%
f_stats, p_value = scipy.stats.f_oneway(l,m,h,axis=0)

# %%
print("F-Statistic={0}, P-value={1}".format(f_stats,p_value))
# Out:
# F-Statistic=36.40764999196599, P-value=1.7105011022702984e-15

# %% [markdown]
# Since the p-value exceeds the significance level of 0.05, we refrain from rejecting the null hypothesis due to a lack of statistical significance.

# %% [markdown]
# Can we conclude that there is no relationship between Nitric oxide concentrations and proportion of non-retail business acres per town? (Pearson Correlation)

# %%
pearson,p_value = scipy.stats.pearsonr(df["NOX"],df["INDUS"])

# %%
print("Pearson Coefficient value={0}, P-value={1}".format(pearson,p_value))
# Out:
# Pearson Coefficient value=0.763651446920915, P-value=7.913361061239593e-98

# %% [markdown]
# Given the p-value is less than 0.05, we can confidently reject the null hypothesis and establish a connection between Nitric Oxide and non-retail business acres per town.

# %% [markdown]
# What is the impact of an additional weighted distance to the five Boston employment centres on the median value of owner occupied homes? (Regression analysis)

# %% [markdown]
# Null Hypothesis: There is no significant relationship between weighted distances to five Boston employment centers and median value.
#
# Alternative Hypothesis: There is a significant relationship between weighted distances to five Boston employment centers and median value.

# %%
y = df['MEDV']
x = df['DIS']

# %%
x = sm.add_constant(x)

# %%
resume = sm.OLS(y,x).fit()

# %%
resume.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Thu, 10 Aug 2023   Prob (F-statistic):           1.21e-08
# Time:                        21:52:25   Log-Likelihood:                -1823.9
# No. Observations:                 506   AIC:                             3652.
# Df Residuals:                     504   BIC:                             3660.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         18.3901      0.817     22.499      0.000      16.784      19.996
# ...

# %%
np.sqrt(0.062)
# Out:
# 0.24899799195977465

# %% [markdown]
# The square root of R-squared is 0.25, indicating a low correlation between the two features.

# %%
df.corr()
# Out:
#             Unnamed: 0      CRIM        ZN     INDUS      CHAS       NOX  \
# Unnamed: 0    1.000000  0.407407 -0.103393  0.399439 -0.003759  0.398736
# CRIM          0.407407  1.000000 -0.200469  0.406583 -0.055892  0.420972
# ZN           -0.103393 -0.200469  1.000000 -0.533828 -0.042697 -0.516604
# INDUS         0.399439  0.406583 -0.533828  1.000000  0.062938  0.763651
# CHAS         -0.003759 -0.055892 -0.042697  0.062938  1.000000  0.091203
# NOX           0.398736  0.420972 -0.516604  0.763651  0.091203  1.000000
# RM           -0.079971 -0.219247  0.311991 -0.391676  0.091251 -0.302188
# AGE           0.203784  0.352734 -0.569537  0.644779  0.086518  0.731470
# DIS          -0.302211 -0.379670  0.664408 -0.708027 -0.099176 -0.769230
# RAD           0.686002  0.625505 -0.311948  0.595129 -0.007368  0.611441
# TAX           0.666626  0.582764 -0.314563  0.720760 -0.035587  0.668023
# PTRATIO       0.291074  0.289946 -0.391679  0.383248 -0.121515  0.188933
# ...

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df.corr(),cmap="coolwarm",annot=True,fmt='.2f',linewidths=2, cbar=False)
plt.show()
